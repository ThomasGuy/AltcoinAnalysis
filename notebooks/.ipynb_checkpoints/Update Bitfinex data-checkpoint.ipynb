# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

# %%
remote = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
db_name = 'sqlite:///c:\\data\\sqlite\\db\\tickToc15m.db'
Session = db_session(remote)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
bab = CoinData('bab', getDBdata, session)
btg = CoinData('btg', getDBdata, session)
dsh = CoinData('dsh', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
iot = CoinData('iot', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
zec = CoinData('zec', getDBdata, session)
edo = CoinData('edo', getDBdata, session)
elf = CoinData('elf', getDBdata, session)
gnt = CoinData('gnt', getDBdata, session)
qsh = CoinData('qsh', getDBdata, session)
qtm = CoinData('qtm', getDBdata, session)
san = CoinData('san', getDBdata, session)
avt = CoinData('avt', getDBdata, session)
fun = CoinData('fun', getDBdata, session)
rcn = CoinData('rcn', getDBdata, session)
rlc = CoinData('rlc', getDBdata, session)
spk = CoinData('spk', getDBdata, session)
bchsv = CoinData('bchsv', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
btc.setParams(**opts)

# %%
session.rollback()
CoinData.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 3443.6000 --> "Sell"  since 2019/01/11 14:15 UTC, - 24hrs   -1.77 %  last week   -2.39 %
# Bitcoin Cash ABC (BAB)      = $  113.7100 --> "Sell"  since 2018/12/31 14:15 UTC, - 24hrs   -4.52 %  last week   -5.44 %
# Bitcoin Gold (BTG)          = $    9.2713 --> "Sell"  since 2018/12/31 01:00 UTC, - 24hrs   -4.27 %  last week  -12.59 %
# Dash (DSH)                  = $   66.2120 --> "Sell"  since 2019/01/28 14:00 UTC, - 24hrs   -4.11 %  last week   -5.71 %
# Eosio (EOS)                 = $    2.3433 --> "Sell"  since 2019/01/28 08:15 UTC, - 24hrs   -2.83 %  last week   -1.17 %
# Ethereum Classic (ETC)      = $    3.7307 --> "Sell"  since 2019/01/08 14:15 UTC, - 24hrs   -4.87 %  last week   -8.35 %
# Ethereum (ETH)              = $  103.9700 --> "Sell"  since 2019/01/22 02:15 UTC, - 24hrs   -4.21 %  last week   -6.41 %
# Iota (IOT)                  = $    0.2432 --> "Sell"  since 2019/01/25 14:15 UTC, - 24hrs   -5.92 %  last week   -8.87 %
# Litecoin (LTC)              = $   32.9300 --> "Buy "  since 2019/02/02 08:15 UTC, - 24hrs   -4.56 %  last week +  1.78 %
# Neon (NEO)                  = $    6.9097 --> "Sell"  since 2019/01/21 20:15 UTC, - 24hrs   -1.92 %  last week   -4.07 %
# Stella Lumen (XLM)          = $    0.0737 --> "Sell"  since 2019/01/25 08:15 UTC, - 24hrs   -7.02 %  last week  -16.69 %
# Monero (XMR)                = $   43.0450 --> "Sell"  since 2019/01/29 02:15 UTC, - 24hrs   -1.26 %  last week   -4.59 %
# Ripple (XRP)                = $    0.2938 --> "Sell"  since 2019/01/12 08:15 UTC, - 24hrs   -2.39 %  last week   -9.12 %
# Zcash (ZEC)                 = $   46.7067 --> "Sell"  since 2019/01/22 02:00 UTC, - 24hrs   -3.98 %  last week   -7.45 %
# Eidoo (EDO)                 = $    0.6643 --> "Sell"  since 2019/01/13 20:00 UTC, - 24hrs +  1.12 %  last week   -4.69 %
# aelf (ELF)                  = $    0.1040 --> "Sell"  since 2018/10/27 21:00 UTC, - 24hrs   -1.30 %  last week +   nan %
# Golem (GNT)                 = $    0.0543 --> "Sell"  since 2019/01/04 01:00 UTC, - 24hrs   -6.62 %  last week   -7.74 %
# QASH (QSH)                  = $    0.0580 --> "Buy "  since 2018/10/17 03:00 UTC, - 24hrs +   nan %  last week  -20.55 %
# Qtum (QTM)                  = $    1.7585 --> "Sell"  since 2019/01/12 06:00 UTC, - 24hrs   -3.91 %  last week   -7.71 %
# Santiment (SAN)             = $    0.3840 --> "Sell"  since 2019/01/12 08:00 UTC, - 24hrs   -3.99 %  last week + 12.43 %
# Aventus (AVT)               = $    0.1386 --> "Sell"  since 2018/11/10 15:00 UTC, - 24hrs +   nan %  last week   -8.79 %
# FunFair (FUN)               = $    0.0039 --> "Sell"  since 2018/08/23 21:00 UTC, - 24hrs   -1.35 %  last week +  0.58 %
# Ripio Credit Network (RCN)  = $    0.0100 --> "Sell"  since 2018/11/13 09:00 UTC, - 24hrs   -7.86 %  last week   -6.35 %
# iExec (RLC)                 = $    0.2327 --> "Sell"  since 2018/11/10 18:00 UTC, - 24hrs +   nan %  last week +  3.39 %
# SpankChain (SPK)            = $    0.0106 --> "Sell"  since 2018/05/11 00:00 UTC, - 24hrs   -1.68 %  last week +   nan %
# Bitcoin SV (BCHSV)          = $   58.0400 --> "Sell"  since 2018/12/29 02:15 UTC, - 24hrs   -6.19 %  last week  -13.70 %

# %%
btc.portfolio.price()
# Out:
# Bitcoin (BTC)          = $ 3443.6000
# Bitcoin Cash ABC (BAB) = $  113.7100
# Bitcoin Gold (BTG)     = $    9.2713
# Dash (DSH)             = $   66.2120
# Eosio (EOS)            = $    2.3433
# Ethereum Classic (ETC) = $    3.7307
# Ethereum (ETH)         = $  103.9700
# Iota (IOT)             = $    0.2432
# Litecoin (LTC)         = $   32.9300
# Neon (NEO)             = $    6.9097
# Stella Lumen (XLM)     = $    0.0737
# Monero (XMR)           = $   43.0450
# Ripple (XRP)           = $    0.2938
# Zcash (ZEC)            = $   46.7067
# Eidoo (EDO)            = $    0.6643
# aelf (ELF)             = $    0.1040
# Golem (GNT)            = $    0.0543
# QASH (QSH)             = $    0.0580
# Qtum (QTM)             = $    1.7585
# Santiment (SAN)        = $    0.3840
# Aventus (AVT)          = $    0.1386
# FunFair (FUN)          = $    0.0039
# Ripio Credit Network (RCN) = $    0.0100
# iExec (RLC)            = $    0.2327
# SpankChain (SPK)       = $    0.0106
# Bitcoin SV (BCHSV)     = $   58.0400

# %%
session.rollback()
start = '2019'
btc.plot(start)

# %%
bab.plot(start)

# %%
btg.plot(start)

# %%
dsh.plot(start)

# %%
eos.plot(start)

# %%
etc.plot(start)

# %%
eth.plot(start)

# %%
iot.plot(start)

# %%
ltc.plot(start)

# %%
neo.plot(start)

# %%
xlm.plot(start)

# %%
xmr.plot(start)

# %%
xrp.plot('2019')

# %%
zec.plot(start)

# %%
edo.plot(start)

# %%
elf.plot(start)

# %%
gnt.plot(start)

# %%
qsh.plot(start)

# %%
qtm.plot(start)

# %%
san.plot(start)

# %%
avt.plot(start)

# %%
fun.plot(start)

# %%
rcn.plot(start)

# %%
rlc.plot(start)

# %%
spk.plot(start)

# %%
bchsv.plot(start)

# %%
btc.plotCandles(days=90)
