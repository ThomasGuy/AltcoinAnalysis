# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from Altcoin.altcoin.getData import getData, showName
from Altcoin.altcoin.coinData import CoinData
from Altcoin.altcoin.getBitfinexCandles import updateAll
from TickTocTest.ticktoctest.tickToc import getDBdata

# %%
updateAll()
# Out:
# limit for 1h = 6
# limit for 3h = 2
# limit for 6h = 1
# limit for 12h = 1
# limit for 1D = 1

# %%
btc = CoinData('btc')
bch = CoinData('bch')
eos = CoinData('eos')
ltc = CoinData('ltc')
xrp = CoinData('xrp')
bch = CoinData('bch')
eth = CoinData('eth')
iot = CoinData('iot')
neo = CoinData('neo')
omg = CoinData('omg')
xmr = CoinData('xmr')
etc = CoinData('etc')
trx = CoinData('trx')
dsh = CoinData('dsh')

# %%
CoinData.portfolio.position()
# Out:
# Bitcoin (BTC)          = $ 4638.00 --> "Sell"  since 2018/11/10 18:00 UTC, - 24hrs +  2.88 %  last week -21.15 %
# Eosio (EOS)            = $    3.86 --> "Sell"  since 2018/11/10 00:00 UTC, - 24hrs +  3.73 %  last week -18.91 %
# Litecoin (LTC)         = $   35.08 --> "Sell"  since 2018/11/09 12:00 UTC, - 24hrs +  5.98 %  last week -22.41 %
# Ripple (XRP)           = $    0.45 --> "Sell"  since 2018/11/20 12:00 UTC, - 24hrs +  3.00 %  last week  -4.91 %
# Bitcoin Cash (BCH)     = $  275.00 --> "Sell"  since 2018/11/10 06:00 UTC, - 24hrs -39.75 %  last week -53.70 %
# Ethereum (ETH)         = $  138.15 --> "Sell"  since 2018/11/11 06:00 UTC, - 24hrs +  4.94 %  last week -25.94 %
# Iota (IOT)             = $    0.33 --> "Sell"  since 2018/11/14 12:00 UTC, - 24hrs +  7.02 %  last week -24.74 %
# Neon (NEO)             = $    9.26 --> "Sell"  since 2018/11/09 12:00 UTC, - 24hrs +  3.83 %  last week -33.15 %
# ...

# %%
# CoinData.setParams(**{'sma': 40, 'bma': 110, 'lma': 300, 'step': '1h'})

# %%
btc.__repr__()
# Out:
# "Moving average parameters - {'sma': 10, 'bma': 27, 'lma': 74, 'step': '6h'}"

# %%
start = '2018-09'
finish = '2019'
btc.plot(start)

# %%
btc.trendPlot(start)

# %%
etc.plot(start)

# %%
dsh.plot(start)

# %%
btc.plotCandles()

# %%
xrp.plotCandles()

# %%
eos.plot(start)

# %%
eos.trendPlot(start)

# %%
ltc.plot(start)

# %%
xmr.plot(start)

# %%
xmr.trendPlot()

# %%
iot.plot(start)

# %%
trx.plot(start)

# %%
neo.plot(start)

# %%
omg.plot(start)

# %% [markdown]
# # DBdata plots

# %%
eos.trendPlot()

# %%
nano = CoinData('nano', getDBdata)
nano.trendPlot()

# %%
steem = CoinData('steem', getDBdata)
steem.trendPlot(start,finish)

# %%
btc.plotCandles()

# %%
btc.plot('2017-07')

# %%
tot = 0
for coin in CoinData.portfolio.values():
    trend, data = coin.trendFollower(start,finish)
    tot += trend['Profit'].iloc[-1]
tot*100/len(CoinData.portfolio)
# Out:
# 74.9945564001666

# %%
CoinData.portfolio.__repr__()
# Out:
# 'Bitcoin (BTC),\nEosio (EOS),\nLitecoin (LTC),\nRipple (XRP),\nBitcoin Cash (BCH),\nEthereum (ETH),\nIota (IOT),\nNeon (NEO),\nOmisego (OMG),\nMonero (XMR),\nEthereum Classic (ETC),\nTron (TRX),\nDash (DSH),\nNano (NANO),\nSteem (STEEM),\n'

# %%
CoinData.portfolio
# Out:
# Bitcoin (BTC),
# Eosio (EOS),
# Litecoin (LTC),
# Ripple (XRP),
# Bitcoin Cash (BCH),
# Ethereum (ETH),
# Iota (IOT),
# Neon (NEO),
# Omisego (OMG),
# Monero (XMR),
# Ethereum Classic (ETC),
# Tron (TRX),
# Dash (DSH),
# Nano (NANO),
# Steem (STEEM),

# %%
CoinData.portfolio.__repr__()
# Out:
# 'Bitcoin (BTC),\nEosio (EOS),\nLitecoin (LTC),\nRipple (XRP),\nBitcoin Cash (BCH),\nEthereum (ETH),\nIota (IOT),\nNeon (NEO),\nOmisego (OMG),\nMonero (XMR),\nEthereum Classic (ETC),\nTron (TRX),\nDash (DSH),\nNano (NANO),\nSteem (STEEM),\n'

# %%
qsh = CoinData('qsh', getDBdata)

# %%
len(CoinData.portfolio)
# Out:
# 16

# %%
qsh.plot(start)

# %%
qtm = CoinData('qtm', getDBdata)

# %%
qtm.plot(start)

# %%
san = CoinData('san', getDBdata)

# %%
san.plot(start)

# %%
san.trendPlot(start, finish)

# %%
CoinData.portfolio.__repr__()
# Out:
# 'Bitcoin (BTC),\nEosio (EOS),\nLitecoin (LTC),\nRipple (XRP),\nBitcoin Cash (BCH),\nEthereum (ETH),\nIota (IOT),\nNeon (NEO),\nOmisego (OMG),\nMonero (XMR),\nEthereum Classic (ETC),\nTron (TRX),\nDash (DSH),\nNano (NANO),\nSteem (STEEM),\nQASH (QSH),\nQtum (QTM),\nSantiment (SAN),\n'

# %%
trx.portfolio
# Out:
# Bitcoin (BTC),
# Eosio (EOS),
# Litecoin (LTC),
# Ripple (XRP),
# Bitcoin Cash (BCH),
# Ethereum (ETH),
# Iota (IOT),
# Neon (NEO),
# Omisego (OMG),
# Monero (XMR),
# Ethereum Classic (ETC),
# Tron (TRX),
# Dash (DSH),
# Nano (NANO),
# Steem (STEEM),
# QASH (QSH),
# Qtum (QTM),
# Santiment (SAN),

# %%
trx.plot(start, finish)

# %% [raw]
# df, cross = omg.getCoinData()

# %%
omg.plotCandles(days=15)

# %%
omg.plot(start)

# %%
omg.value
# Out:
# 2.039

# %%
btc.value
# Out:
# 4679.2
