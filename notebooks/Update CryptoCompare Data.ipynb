# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

# %%
remote = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
db_name = 'sqlite:///c:\\data\\sqlite\\db\\tickToc15m.db'
Session = db_session(master)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
bch = CoinData('bch', getDBdata, session)
ae = CoinData('ae', getDBdata, session)
bnb = CoinData('bnb', getDBdata, session)
icx = CoinData('icx', getDBdata, session)
ont = CoinData('ont', getDBdata, session)
xem = CoinData('xem', getDBdata, session)
zil = CoinData('zil', getDBdata, session)
omg = CoinData('omg', getDBdata, session)
zrx = CoinData('zrx', getDBdata, session)
dcr = CoinData('dcr', getDBdata, session)
ada = CoinData('ada', getDBdata, session)
lsk = CoinData('lsk', getDBdata, session)
trx = CoinData('trx', getDBdata, session)
nano = CoinData('nano', getDBdata, session)
steem = CoinData('steem', getDBdata, session)
ven = CoinData('ven', getDBdata, session)
waves = CoinData('waves', getDBdata, session)
xvg = CoinData('xvg', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
btc.setParams(**opts)

# %%
print(repr(CoinData.portfolio))
# Out:
# Bitcoin (BTC),
# Bitcoin Cash (BCH),
# Aeternity (AE),
# Binance (BNB),
# ICON (ICX),
# Ontology (ONT),
# NEM (XEM),
# Zilliqa (ZIL),
# Omisego (OMG),
# Ox (ZRX),
# Decred (DCR),
# Cardano (ADA),
# Lisk (LSK),
# Tron (TRX),
# Nano (NANO),
# Steem (STEEM),
# VeChain (VEN),
# Waves (WAVES),
# Verge (XVG),

# %%
session.rollback()
CoinData.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 3893.6000 --> "Sell"  since 2019/03/02 06:45 UTC, - 24hrs   -0.34 %  last week +  0.40 %
# Bitcoin Cash (BCH)          = $  129.8500 --> "Sell"  since 2019/02/28 12:45 UTC, - 24hrs   -0.45 %  last week   -2.15 %
# Aeternity (AE)              = $    0.4451 --> "Buy "  since 2019/02/09 12:45 UTC, - 24hrs +  0.41 %  last week +  2.70 %
# Binance (BNB)               = $   11.8100 --> "Buy "  since 2019/03/02 18:45 UTC, - 24hrs   -5.29 %  last week + 12.16 %
# ICON (ICX)                  = $    0.2831 --> "Buy "  since 2019/02/09 00:45 UTC, - 24hrs +  1.47 %  last week + 15.98 %
# Ontology (ONT)              = $    0.8844 --> "Buy "  since 2019/02/10 00:45 UTC, - 24hrs   -0.39 %  last week  -14.14 %
# NEM (XEM)                   = $    0.0424 --> "Sell"  since 2019/03/02 06:45 UTC, - 24hrs   -0.26 %  last week   -2.82 %
# Zilliqa (ZIL)               = $    0.0171 --> "Sell"  since 2019/02/27 12:45 UTC, - 24hrs   -0.29 %  last week   -0.23 %
# ...

# %%
btc.portfolio.price()
# Out:
# Bitcoin (BTC)          = $ 3886.3000
# Bitcoin Cash (BCH)     = $  129.9200
# Aeternity (AE)         = $    0.4436
# Binance (BNB)          = $   11.8500
# ICON (ICX)             = $    0.2835
# Ontology (ONT)         = $    0.8795
# NEM (XEM)              = $    0.0421
# Zilliqa (ZIL)          = $    0.0170
# Omisego (OMG)          = $    1.2700
# Ox (ZRX)               = $    0.2404
# Decred (DCR)           = $   16.6300
# Cardano (ADA)          = $    0.0432
# Lisk (LSK)             = $    1.2200
# Tron (TRX)             = $    0.0232
# Nano (NANO)            = $    0.8922
# Steem (STEEM)          = $    0.3936
# VeChain (VEN)          = $    0.0780
# Waves (WAVES)          = $    2.7100
# Verge (XVG)            = $    0.0067

# %%
# session.rollback()
start = '2019'
btc.plot(start)

# %%
omg.plot('2019')

# %%
ada.plot(start)

# %%
bch.plot(start)

# %%
# session.rollback()
trx.plot(start)

# %%
ae.plot(start)

# %%
bnb.plot(start)

# %%
icx.plot(start)

# %%
ont.plot(start)

# %%
xem.plot(start)

# %%
zil.plot(start)

# %%
zrx.plot(start)

# %%
dcr.plot(start)

# %%
lsk.plot(start)

# %%
nano.plot(start)

# %%
steem.plot(start)

# %%
ven.plot('2018')

# %%
waves.plot(start)

# %%
xvg.plot(start)

# %%
btc.plotCandles(days=50)

# %%
bch.plot('2018')
