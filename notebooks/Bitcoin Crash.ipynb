# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData
DATABASE_URI = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
local_db = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
Session = db_session(DATABASE_URI)

# %%
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
trx = CoinData('trx', getDBdata, session)
zrx = CoinData('zrx', getDBdata, session)
nano = CoinData('nano', getDBdata, session)

# %%
CoinData.setParams(**{'sma': 20, 'bma': 55, 'lma': 140, 'step': '6h'})

# %%
btc.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 4122.6000 --> "Buy "  since 2019/01/06 23:00 UTC, - 24hrs +  0.18 %  last week +  6.33 %
# Neon (NEO)                  = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -35.63 %
# Litecoin (LTC)              = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -84.43 %
# Ethereum (ETH)              = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -96.47 %
# Ripple (XRP)                = $    5.0629 --> "Buy "  since 2019/01/07 05:00 UTC, - 24hrs +  1.90 %  last week + 1266.87 %
# Tron (TRX)                  = $    0.0267 --> "Buy "  since 2019/01/05 11:00 UTC, - 24hrs + 12.69 %  last week + 34.73 %
# Ox (ZRX)                    = $    0.3270 --> "Buy "  since 2019/01/07 11:00 UTC, - 24hrs +  1.36 %  last week +  5.79 %
# Nano (NANO)                 = $    0.9732 --> "Buy "  since 2019/01/07 17:00 UTC, - 24hrs +  0.54 %  last week +  2.21 %

# %%
CoinData.portfolio.price()
# Out:
# Bitcoin (BTC)          = $ 4122.6000
# Neon (NEO)             = $    5.0629
# Litecoin (LTC)         = $    5.0629
# Ethereum (ETH)         = $    5.0629
# Ripple (XRP)           = $    5.0629
# Tron (TRX)             = $    0.0267
# Ox (ZRX)               = $    0.3270
# Nano (NANO)            = $    0.9732

# %%
[li for li in CoinData.portfolio.keys()]
# Out:
# ['btc', 'neo', 'ltc', 'eth', 'xrp', 'trx', 'zrx', 'nano']

# %%
print(repr(CoinData.portfolio))
# Out:
# Bitcoin (BTC),
# Neon (NEO),
# Litecoin (LTC),
# Ethereum (ETH),
# Ripple (XRP),
# Tron (TRX),
# Ox (ZRX),
# Nano (NANO),

# %%
start = '2018-10'
btc.plot(start)

# %%
session.rollback()
btc.trendPlot(start='2017-10')

# %%
zrx.plot(start)

# %%
trx.plot(start)

# %%
xrp.plot(start)

# %%
nano.plot(start)

# %%
ltc.plot(start)

# %%
eth.plot(start)

# %%
neo.plot(start)
