# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData
DATABASE_URI = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
Session = db_session(master)

# %%
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
trx = CoinData('trx', getDBdata, session)
iot = CoinData('iot', getDBdata, session)
eos = CoinData('eos', getDBdata, session)

# %%
CoinData.setParams(**{'sma': 20, 'bma': 55, 'lma': 140, 'step': '6h'})

# %%
btc.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 3697.9402 --> "Buy "  since 2019/02/09 08:00 UTC, - 24hrs +  0.35 %  last week +  5.93 %
# Neon (NEO)                  = $    8.0513 --> "Buy "  since 2019/02/09 08:00 UTC, - 24hrs +  4.49 %  last week + 11.82 %
# Litecoin (LTC)              = $   45.0600 --> "Buy "  since 2019/02/02 08:00 UTC, - 24hrs +  1.31 %  last week + 31.35 %
# Ethereum (ETH)              = $  124.1600 --> "Buy "  since 2019/02/09 08:00 UTC, - 24hrs +  4.50 %  last week + 14.52 %
# Ripple (XRP)                = $    0.3101 --> "Buy "  since 2019/02/10 02:00 UTC, - 24hrs +  0.69 %  last week +  1.91 %
# Tron (TRX)                  = $    0.0259 --> "Sell"  since 2019/02/02 20:00 UTC, - 24hrs   -0.27 %  last week   -5.02 %
# Iota (IOT)                  = $    0.2743 --> "Buy "  since 2019/02/09 08:00 UTC, - 24hrs   -0.66 %  last week +  7.72 %
# Eosio (EOS)                 = $    2.8267 --> "Buy "  since 2019/02/08 14:00 UTC, - 24hrs +  3.32 %  last week + 16.81 %

# %%
CoinData.portfolio.price()
# Out:
# Bitcoin (BTC)          = $ 3697.9402
# Neon (NEO)             = $    8.0513
# Litecoin (LTC)         = $   45.0600
# Ethereum (ETH)         = $  124.1600
# Ripple (XRP)           = $    0.3101
# Tron (TRX)             = $    0.0259
# Iota (IOT)             = $    0.2743
# Eosio (EOS)            = $    2.8267

# %%
[li for li in CoinData.portfolio.keys()]
# Out:
# ['btc', 'neo', 'ltc', 'eth', 'xrp', 'trx', 'iot', 'eos']

# %%
print(repr(CoinData.portfolio))
# Out:
# Bitcoin (BTC),
# Neon (NEO),
# Litecoin (LTC),
# Ethereum (ETH),
# Ripple (XRP),
# Tron (TRX),
# Iota (IOT),
# Eosio (EOS),

# %%
start = '2018-10'
btc.plot(start)

# %%
session.rollback()
btc.trendPlot(start='2017-10')

# %%
iot.plot(start)

# %%
trx.plot(start)

# %%
xrp.plot(start)

# %%
eos.plot(start)

# %%
ltc.plot(start)

# %%
eth.plot(start)

# %%
neo.plot(start)
