# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

# %%
remote = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
db_name = 'sqlite:///c:\\data\\sqlite\\db\\tickToc15m.db'
Session = db_session(master)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
bab = CoinData('bab', getDBdata, session)
btg = CoinData('btg', getDBdata, session)
dsh = CoinData('dsh', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
iot = CoinData('iot', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
zec = CoinData('zec', getDBdata, session)
edo = CoinData('edo', getDBdata, session)
elf = CoinData('elf', getDBdata, session)
gnt = CoinData('gnt', getDBdata, session)
qsh = CoinData('qsh', getDBdata, session)
qtm = CoinData('qtm', getDBdata, session)
san = CoinData('san', getDBdata, session)
trx = CoinData('trx', getDBdata, session)
# fun = CoinData('fun', getDBdata, session)
# rcn = CoinData('rcn', getDBdata, session)
rlc = CoinData('rlc', getDBdata, session)
# spk = CoinData('spk', getDBdata, session)
bchsv = CoinData('bchsv', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
btc.setParams(**opts)

# %%
session.rollback()
CoinData.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 3953.0000 --> "Sell"  since 2019/03/02 04:15 UTC, - 24hrs +  3.59 %  last week +  0.69 %
# Bitcoin Cash ABC (BAB)      = $  135.0400 --> "Sell"  since 2019/02/28 16:15 UTC, - 24hrs +  5.49 %  last week   -0.60 %
# Bitcoin Gold (BTG)          = $   12.7510 --> "Sell"  since 2019/03/03 22:15 UTC, - 24hrs +  5.20 %  last week   -2.45 %
# Dash (DSH)                  = $   83.3380 --> "Sell"  since 2019/02/27 22:15 UTC, - 24hrs +  3.55 %  last week +  1.51 %
# Eosio (EOS)                 = $    3.8829 --> "Sell"  since 2019/03/02 16:15 UTC, - 24hrs + 14.33 %  last week +  8.80 %
# Ethereum Classic (ETC)      = $    4.3654 --> "Sell"  since 2019/02/28 04:15 UTC, - 24hrs +  3.56 %  last week   -1.64 %
# Ethereum (ETH)              = $  141.6300 --> "Sell"  since 2019/02/28 22:15 UTC, - 24hrs +  8.53 %  last week   -0.25 %
# Iota (IOT)                  = $    0.2840 --> "Sell"  since 2019/02/28 04:15 UTC, - 24hrs +  1.02 %  last week   -2.40 %
# ...

# %%
btc.portfolio.price()
# Out:
# Bitcoin (BTC)          = $ 3953.0000
# Bitcoin Cash ABC (BAB) = $  135.0400
# Bitcoin Gold (BTG)     = $   12.7510
# Dash (DSH)             = $   83.3380
# Eosio (EOS)            = $    3.8829
# Ethereum Classic (ETC) = $    4.3654
# Ethereum (ETH)         = $  141.6300
# Iota (IOT)             = $    0.2840
# Litecoin (LTC)         = $   56.3560
# Neon (NEO)             = $    8.9756
# Stella Lumen (XLM)     = $    0.0866
# Monero (XMR)           = $   50.4150
# Ripple (XRP)           = $    0.3220
# Zcash (ZEC)            = $   51.4370
# Eidoo (EDO)            = $    0.7801
# aelf (ELF)             = $    0.1537
# Golem (GNT)            = $    0.0644
# QASH (QSH)             = $    0.1110
# Qtum (QTM)             = $    2.0938
# Santiment (SAN)        = $    0.5203
# Tron (TRX)             = $    0.0238
# iExec (RLC)            = $    0.3580
# Bitcoin SV (BCHSV)     = $   66.6600

# %%
session.rollback()
start = '2018-10'
btc.plot(start)

# %%
bab.plot(start)

# %%
btg.plot(start)

# %%
dsh.plot(start)

# %%
eos.plot(start)

# %%
etc.plot(start)

# %%
eth.plot(start)

# %%
iot.plot(start)

# %%
ltc.plot(start)

# %%
neo.plot(start)

# %%
xlm.plot(start)

# %%
xmr.plot(start)

# %%
xrp.plot('2019')

# %%
zec.plot(start)

# %%
edo.plot(start)

# %%
elf.plot(start)

# %%
gnt.plot(start)

# %%
qsh.plot(start)

# %%
qtm.plot(start)

# %%
san.plot(start)

# %%
rlc.plot(start)

# %%
trx.plot(start)

# %%
bchsv.plot(start)

# %%
btc.plotCandles(days=30)
