# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

DB = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
Session = db_session(DB)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
etc.setParams(**opts)

# %%
CoinData.position()
# Out:
# Bitcoin (BTC)               = $ 4034.8000 --> "Sell"  since 2018/12/31 06:45 UTC, - 24hrs +  2.17 %  last week +  2.48 %
# Ethereum Classic (ETC)      = $    5.5189 --> "Buy "  since 2018/12/18 18:45 UTC, - 24hrs +  1.90 %  last week   -3.76 %
# Eosio (EOS)                 = $    2.9240 --> "Buy "  since 2019/01/03 00:45 UTC, - 24hrs +  7.25 %  last week +  9.98 %
# Ethereum (ETH)              = $  158.2900 --> "Buy "  since 2018/12/19 00:45 UTC, - 24hrs +  8.82 %  last week + 17.52 %
# Neon (NEO)                  = $    8.2352 --> "Buy "  since 2018/12/19 00:45 UTC, - 24hrs +  2.05 %  last week +  3.13 %
# Stella Lumen (XLM)          = $    0.1221 --> "Sell"  since 2018/12/30 18:45 UTC, - 24hrs +  2.44 %  last week +  0.03 %
# Monero (XMR)                = $   53.1200 --> "Sell"  since 2018/12/30 06:45 UTC, - 24hrs +  7.37 %  last week +  5.51 %
# Ripple (XRP)                = $    0.3833 --> "Sell"  since 2018/12/31 18:45 UTC, - 24hrs +  2.38 %  last week   -0.91 %
# Litecoin (LTC)              = $   34.1920 --> "Sell"  since 2019/01/01 06:45 UTC, - 24hrs +  3.62 %  last week +  7.67 %

# %%
CoinData.price()
# Out:
# Bitcoin (BTC)          = $ 4034.8000
# Ethereum Classic (ETC) = $    5.5189
# Eosio (EOS)            = $    2.9240
# Ethereum (ETH)         = $  158.2900
# Neon (NEO)             = $    8.2352
# Stella Lumen (XLM)     = $    0.1221
# Monero (XMR)           = $   53.1200
# Ripple (XRP)           = $    0.3833
# Litecoin (LTC)         = $   34.1920

# %%
start = '2018-09'
eth.plot(start)

# %%
ltc.plot(start)

# %%
eos.plot(start)

# %%
neo.plot(start)

# %%
xlm.plot(start)

# %%
xmr.plot(start)

# %%
xrp.plot(start)

# %%
btc.plot(start)

# %%
session = Session()
df, cross = btc.getCoinData()

# %%
df.tail()
# Out:
#                        Open    Close     High     Low       Volume  \
# MTS
# 2019-01-02 00:45:00  3798.2  3948.90  3987.00  3797.1  5949.310730
# 2019-01-02 06:45:00  3949.0  3929.50  3970.90  3922.0  1882.312998
# 2019-01-02 12:45:00  3924.9  3953.13  3967.00  3920.4  1754.929683
# 2019-01-02 18:45:00  3955.0  3999.99  4047.00  3954.9  5166.224333
# 2019-01-03 00:45:00  3999.9  4034.80  4083.47  3975.0  3049.800967
#
#                            sewma          bma          lma
# MTS
# 2019-01-02 00:45:00  3899.553236  3975.216545  3822.084214
# 2019-01-02 06:45:00  3902.405308  3974.696545  3820.977786
# 2019-01-02 12:45:00  3907.236231  3975.324364  3818.985857
# 2019-01-02 18:45:00  3916.069924  3978.236909  3816.664357
# 2019-01-03 00:45:00  3927.377550  3981.833273  3814.770071

# %%
cross
# Out:
#                         Close Transaction
# MTS
# 2018-02-27 00:45:00  10329.00        Sell
# 2018-03-02 00:45:00  10997.00         Buy
# 2018-03-08 12:45:00   9296.80        Sell
# 2018-03-24 06:45:00   8726.10         Buy
# 2018-03-27 00:45:00   7924.00        Sell
# 2018-04-12 12:45:00   7694.80         Buy
# 2018-05-10 18:45:00   9018.00        Sell
# 2018-06-04 12:45:00   7475.90         Buy
# 2018-06-10 12:45:00   6738.10        Sell
# 2018-07-03 00:45:00   6630.10         Buy
# 2018-07-12 12:45:00   6182.90        Sell
# 2018-07-17 12:45:00   7190.20         Buy
# 2018-08-02 06:45:00   7564.80        Sell
# 2018-08-20 12:45:00   6464.60         Buy
# 2018-09-06 18:45:00   6516.10        Sell
# 2018-09-21 00:45:00   6535.10         Buy
# 2018-10-03 12:45:00   6511.17        Sell
# 2018-10-08 06:45:00   6646.90         Buy
# 2018-10-11 06:45:00   6275.70        Sell
# 2018-10-16 00:45:00   6844.70         Buy
# 2018-10-26 12:45:00   6536.80        Sell
# 2018-11-07 12:45:00   6586.94         Buy
# 2018-11-14 12:45:00   5984.90        Sell
# 2018-12-19 06:45:00   3855.40         Buy
# 2018-12-31 06:45:00   3910.50        Sell
