# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

DB = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
Session = db_session(master)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
omg = CoinData('omg', getDBdata, session)
bab = CoinData('bab', getDBdata, session)
iot = CoinData('iot', getDBdata, session)
zec = CoinData('zec', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
etc.setParams(**opts)

# %%
CoinData.position()
# Out:
# Bitcoin (BTC)               = $ 4008.7000 --> "Buy "  since 2019/03/09 12:30 UTC, - 24hrs +  1.23 %  last week +  2.38 %
# Ethereum Classic (ETC)      = $    4.3305 --> "Sell"  since 2019/02/28 06:15 UTC, - 24hrs +  1.31 %  last week   -0.64 %
# Eosio (EOS)                 = $    3.8122 --> "Buy "  since 2019/03/08 06:30 UTC, - 24hrs +  2.48 %  last week +  6.63 %
# Ethereum (ETH)              = $  139.8600 --> "Sell"  since 2019/03/01 00:30 UTC, - 24hrs +  1.65 %  last week +  1.80 %
# Neon (NEO)                  = $    9.1222 --> "Sell"  since 2019/03/03 00:30 UTC, - 24hrs +  1.10 %  last week +  1.96 %
# Stella Lumen (XLM)          = $    0.0921 --> "Buy "  since 2019/03/09 05:45 UTC, - 24hrs +  5.41 %  last week +  7.96 %
# Monero (XMR)                = $   50.6220 --> "Buy "  since 2019/03/08 18:30 UTC, - 24hrs +  1.41 %  last week +  1.98 %
# Ripple (XRP)                = $    0.3191 --> "Sell"  since 2019/03/02 06:30 UTC, - 24hrs +  1.36 %  last week   -0.87 %
# Litecoin (LTC)              = $   58.5380 --> "Buy "  since 2019/03/06 00:30 UTC, - 24hrs +  0.86 %  last week + 17.44 %
# Omisego (OMG)               = $    1.4100 --> "Sell"  since 2019/03/03 12:30 UTC, - 24hrs + 10.16 %  last week +  7.63 %
# Bitcoin Cash ABC (BAB)      = $  135.8300 --> "Sell"  since 2019/02/28 12:30 UTC, - 24hrs +  4.31 %  last week +  1.11 %
# Iota (IOT)                  = $    0.2862 --> "Sell"  since 2019/02/28 06:30 UTC, - 24hrs +  1.33 %  last week   -4.44 %
# Zcash (ZEC)                 = $   51.9800 --> "Sell"  since 2019/02/28 00:30 UTC, - 24hrs +  3.38 %  last week   -0.73 %

# %%
CoinData.price()
start = '2019'
# Out:
# Bitcoin (BTC)          = $ 3999.9000
# Ethereum Classic (ETC) = $    4.3688
# Eosio (EOS)            = $    3.8183
# Ethereum (ETH)         = $  139.6619
# Neon (NEO)             = $    9.1427
# Stella Lumen (XLM)     = $    0.0918
# Monero (XMR)           = $   50.7050
# Ripple (XRP)           = $    0.3191
# Litecoin (LTC)         = $   58.5680
# Omisego (OMG)          = $    1.3300
# Bitcoin Cash ABC (BAB) = $  135.5000
# Iota (IOT)             = $    0.2893
# Zcash (ZEC)            = $   51.1260

# %%
neo.plot(start)

# %%
eos.plot(start)

# %%
omg.plot(start)

# %%
bab.plot(start)

# %%
iot.plot(start)

# %%
zec.plot(start)

# %%
eth.plot(start)

# %%
ltc.plot(start)

# %%
xlm.plot(start)

# %%
xmr.plot(start)

# %%
xrp.plot(start)

# %%
btc.plot(start)

# %%
neo.plotCandles()

# %%
eos.plotCandles()
