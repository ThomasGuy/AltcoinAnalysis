# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

DB = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
Session = db_session(master)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
etc.setParams(**opts)

# %%
CoinData.position()
# Out:
# Bitcoin (BTC)               = $ 3696.2000 --> "Sell"  since 2019/01/11 11:15 UTC, - 24hrs +  0.05 %  last week   -6.11 %
# Ethereum Classic (ETC)      = $    4.5510 --> "Buy "  since 2018/12/18 23:00 UTC, - 24hrs   -4.32 %  last week  -15.18 %
# Eosio (EOS)                 = $    2.4524 --> "Sell"  since 2019/01/11 05:15 UTC, - 24hrs   -0.04 %  last week  -11.79 %
# Ethereum (ETH)              = $  126.9219 --> "Sell"  since 2019/01/10 23:15 UTC, - 24hrs   -1.36 %  last week  -19.12 %
# Neon (NEO)                  = $    7.8270 --> "Sell"  since 2019/01/13 05:15 UTC, - 24hrs   -1.54 %  last week   -2.34 %
# Stella Lumen (XLM)          = $    0.1114 --> "Sell"  since 2018/12/30 23:00 UTC, - 24hrs +  3.70 %  last week   -4.22 %
# Monero (XMR)                = $   45.7850 --> "Buy "  since 2019/01/05 17:00 UTC, - 24hrs +  1.22 %  last week  -11.38 %
# Ripple (XRP)                = $    0.3372 --> "Sell"  since 2019/01/10 17:00 UTC, - 24hrs +  0.48 %  last week   -7.91 %
# Litecoin (LTC)              = $   33.0040 --> "Sell"  since 2019/01/13 05:00 UTC, - 24hrs +  0.83 %  last week  -14.28 %

# %%
CoinData.price()
# Out:
# Bitcoin (BTC)          = $ 3696.2000
# Ethereum Classic (ETC) = $    4.5510
# Eosio (EOS)            = $    2.4524
# Ethereum (ETH)         = $  126.9219
# Neon (NEO)             = $    7.8270
# Stella Lumen (XLM)     = $    0.1114
# Monero (XMR)           = $   45.7850
# Ripple (XRP)           = $    0.3372
# Litecoin (LTC)         = $   33.0040

# %%
start = '2018-09'
eth.plot(start)

# %%
ltc.plot(start)

# %%
eos.plot(start)

# %%
neo.plot(start)

# %%
xlm.plot(start)

# %%
xmr.plot(start)

# %%
xrp.plot(start)

# %%
btc.plot(start)

# %%
session = Session()
df, cross = btc.getCoinData()

# %%
df.tail()
# Out:
#                             Open   Close         High     Low       Volume  \
# MTS
