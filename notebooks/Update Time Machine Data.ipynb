# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

# %%
remote = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
db_name = 'sqlite:///c:\\data\\sqlite\\db\\tickToc15m.db'
Session = db_session(remote)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
bch = CoinData('bch', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
dsh = CoinData('dsh', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
omg = CoinData('omg', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
ada = CoinData('ada', getDBdata, session)
iot = CoinData('iot', getDBdata, session)
trx = CoinData('trx', getDBdata, session)
zec = CoinData('zec', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)

# %%
opts = {'step': '6h', 'sma': 20, 'bma': 55, 'lma': 140}
btc.setParams(**opts)

# %%
print(CoinData.portfolio.__repr__())
# Out:
# Bitcoin (BTC),
# Bitcoin Cash (BCH),
# Eosio (EOS),
# Ethereum (ETH),
# Ripple (XRP),
# Dash (DSH),
# Neon (NEO),
# Stella Lumen (XLM),
# Omisego (OMG),
# Ethereum Classic (ETC),
# Litecoin (LTC),
# Cardano (ADA),
# Iota (IOT),
# Tron (TRX),
# Zcash (ZEC),
# Monero (XMR),

# %%
session.rollback()
CoinData.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 4122.6000 --> "Buy "  since 2019/01/06 23:00 UTC, - 24hrs +  0.18 %  last week +  6.33 %
# Bitcoin Cash (BCH)          = $  161.6100 --> "Sell"  since 2018/12/31 17:00 UTC, - 24hrs +  0.62 %  last week   -0.91 %
# Eosio (EOS)                 = $    2.8658 --> "Buy "  since 2019/01/02 23:00 UTC, - 24hrs +  1.63 %  last week +  5.93 %
# Ethereum (ETH)              = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -96.47 %
# Ripple (XRP)                = $    5.0629 --> "Buy "  since 2019/01/07 05:00 UTC, - 24hrs +  1.90 %  last week + 1266.87 %
# Dash (DSH)                  = $   82.7560 --> "Sell"  since 2018/12/31 05:00 UTC, - 24hrs   -1.98 %  last week +  1.33 %
# Neon (NEO)                  = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -35.63 %
# Stella Lumen (XLM)          = $    5.0629 --> "Buy "  since 2019/01/07 05:00 UTC, - 24hrs +  1.90 %  last week + 4233.56 %
# Omisego (OMG)               = $    1.5300 --> "Buy "  since 2019/01/06 05:00 UTC, - 24hrs +  0.66 %  last week +  9.03 %
# Ethereum Classic (ETC)      = $    5.0629 --> "Buy "  since 2018/12/18 17:00 UTC, - 24hrs +  1.90 %  last week   -4.78 %
# Litecoin (LTC)              = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -84.43 %
# Cardano (ADA)               = $    0.0485 --> "Buy "  since 2019/01/05 11:00 UTC, - 24hrs +  1.52 %  last week + 16.83 %
# Iota (IOT)                  = $    5.0629 --> "Buy "  since 2018/12/18 11:00 UTC, - 24hrs +  1.90 %  last week + 1270.08 %
# Tron (TRX)                  = $    0.0267 --> "Buy "  since 2019/01/05 11:00 UTC, - 24hrs + 12.69 %  last week + 34.73 %
# Zcash (ZEC)                 = $    5.0629 --> "Sell"  since 2018/12/30 23:00 UTC, - 24hrs +  1.90 %  last week  -91.54 %
# Monero (XMR)                = $    5.0629 --> "Sell"  since 2019/01/07 11:00 UTC, - 24hrs +  1.90 %  last week  -89.60 %

# %%
btc.portfolio.price()
# Out:
# Bitcoin (BTC)          = $ 4122.6000
# Bitcoin Cash (BCH)     = $  161.6100
# Eosio (EOS)            = $    2.8658
# Ethereum (ETH)         = $    5.0629
# Ripple (XRP)           = $    5.0629
# Dash (DSH)             = $   82.7560
# Neon (NEO)             = $    5.0629
# Stella Lumen (XLM)     = $    5.0629
# Omisego (OMG)          = $    1.5300
# Ethereum Classic (ETC) = $    5.0629
# Litecoin (LTC)         = $    5.0629
# Cardano (ADA)          = $    0.0485
# Iota (IOT)             = $    5.0629
# Tron (TRX)             = $    0.0267
# Zcash (ZEC)            = $    5.0629
# Monero (XMR)           = $    5.0629

# %%
# session.rollback()
start = '2018-09'
bch.plot(start)

# %%
ada.plot(start)

# %%
iot.plot(start)

# %%
# session.rollback()
trx.plot(start)

# %%
omg.plot(start)

# %%
eth.plot(start)

# %%
eos.plot(start)

# %%
zec.plot(start)

# %%
xlm.plot(start)

# %%
ltc.plot(start)

# %%
xrp.plot(start)

# %%
eos.plot(start)

# %%
neo.plot(start)

# %%
dsh.plot(start)

# %%
trx.plot(start)

# %%
xmr.plot(start)

# %%
eos.plotCandles(days=67)

# %%
btc.plotCandles(days=40)

# %%
btc.plot('2018-05')
