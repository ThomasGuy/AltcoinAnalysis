# %%
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session
from Altcoin.altcoin.coinData import CoinData

# %%
remote = 'mysql+pymysql://TomRoot:Sporty66@mysql.stackcp.com:51228/ticktoctestDB-3637742e'
master = f'sqlite:///c:\\data\\sqlite\\db\\master_db.db'
db_name = 'sqlite:///c:\\data\\sqlite\\db\\tickToc15m.db'
Session = db_session(master)
session = Session()

# %%
btc = CoinData('btc', getDBdata, session)
bch = CoinData('bch', getDBdata, session)
eos = CoinData('eos', getDBdata, session)
eth = CoinData('eth', getDBdata, session)
xrp = CoinData('xrp', getDBdata, session)
dsh = CoinData('dsh', getDBdata, session)
neo = CoinData('neo', getDBdata, session)
xlm = CoinData('xlm', getDBdata, session)
omg = CoinData('omg', getDBdata, session)
etc = CoinData('etc', getDBdata, session)
ltc = CoinData('ltc', getDBdata, session)
ada = CoinData('ada', getDBdata, session)
iot = CoinData('iot', getDBdata, session)
trx = CoinData('trx', getDBdata, session)
zec = CoinData('zec', getDBdata, session)
xmr = CoinData('xmr', getDBdata, session)

# %%
opts = {'step': '1D', 'sma': 20, 'bma': 55, 'lma': 140}
btc.setParams(**opts)

# %%
print(CoinData.portfolio.__repr__())
# Out:
# Bitcoin (BTC),
# Bitcoin Cash (BCH),
# Eosio (EOS),
# Ethereum (ETH),
# Ripple (XRP),
# Dash (DSH),
# Neon (NEO),
# Stella Lumen (XLM),
# Omisego (OMG),
# Ethereum Classic (ETC),
# Litecoin (LTC),
# Cardano (ADA),
# Iota (IOT),
# Tron (TRX),
# Zcash (ZEC),
# Monero (XMR),

# %%
session.rollback()
CoinData.portfolio.position()
# Out:
# Bitcoin (BTC)               = $ 3664.4000 --> "Sell"  since 2018/11/03 06:00 UTC, - 24hrs   -0.41 %  last week  -11.04 %
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-11692e288c96> in <module>()
#       1 session.rollback()
# ----> 2 CoinData.portfolio.position()
#
# ~\MyPython\Altcoin\altcoin\coinData.py in position(self)
#     140
#     141         for coin, data in self.items():
# --> 142             dataf, cross = data.getCoinData()
#     143             now = dataf.index[-1]
#     144             day = _amount(now, dataf.loc[now - timedelta(1):].index[0])
#
# ~\MyPython\Altcoin\altcoin\coinData.py in getCoinData(self)
#     206     def getCoinData(self):
#     207         dataf = self._init_DF(**self.params)
# --> 208         return (dataf, self._crossover(dataf[self.params['bma'] - 1:]))
#     209
#     210     def _init_DF(self, sma, bma, lma, step):
#
# ~\MyPython\Altcoin\altcoin\coinData.py in _crossover(self, dataset)
#     237          of the small and medium moving averages"""
#     238         record = []
# --> 239         Higher = dataset.iloc[0]['sewma'] > dataset.iloc[0]['bma']
#     240         # initialize record[] ensures record is never empty
#     241         if Higher:
#
# c:\users\twguy\mypython\altcoin\myenv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# c:\users\twguy\mypython\altcoin\myenv\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# c:\users\twguy\mypython\altcoin\myenv\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
btc.portfolio.price()

# %%
# session.rollback()
start = '2018-09'
btc.plot(start)

# %%
ada.plot(start)

# %%
iot.plot(start)

# %%
# session.rollback()
trx.plot(start)

# %%
omg.plot(start)

# %%
eth.plot(start)

# %%
eos.plot(start)

# %%
zec.plot(start)

# %%
xlm.plot(start)

# %%
ltc.plot(start)

# %%
xrp.plot(start)

# %%
eos.plot(start)

# %%
neo.plot(start)

# %%
dsh.plot(start='2017-11', finish='2018-02')

# %%
trx.plot(start)

# %%
xmr.plot(start)

# %%
eos.plotCandles(days=67)

# %%
btc.plotCandles(days=40)

# %%
btc.plot('2018-09')
