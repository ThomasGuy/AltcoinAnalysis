# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from Altcoin.altcoin.getData import getData
from Altcoin.altcoin.coinData import CoinData
from Altcoin.altcoin.getBitfinexCandles import updateAll
from TickTocTest.ticktoctest.tickToc import getDBdata, db_session

# %%
updateAll()
# Out:
# limit for 1h = 96
# limit for 3h = 32
# limit for 6h = 16
# limit for 12h = 8
# limit for 1D = 4

# %%
neo = CoinData('neo', getData)
eth = CoinData('eth', getData)
xrp = CoinData('xrp', getData)
ltc = CoinData('ltc', getData)
iot = CoinData('iot', getData)
eos = CoinData('eos', getData)
btc = CoinData('btc', getData)

# %%
CoinData.setParams(**{'sma': 20, 'bma': 55, 'lma': 140, 'step': '6h'})

# %%
CoinData.position()
# Out:
# Neon (NEO)                  = $    9.3355 --> "Buy "  since 2018/12/18 18:00 UTC, - 24hrs +  8.13 %  last week + 15.36 %
# Ethereum (ETH)              = $  153.9219 --> "Buy "  since 2018/12/19 00:00 UTC, - 24hrs   -0.56 %  last week +  6.15 %
# Ripple (XRP)                = $    0.3745 --> "Sell"  since 2018/12/31 12:00 UTC, - 24hrs +  0.28 %  last week   -0.70 %
# Litecoin (LTC)              = $   40.3550 --> "Buy "  since 2019/01/02 18:00 UTC, - 24hrs +  4.41 %  last week + 22.51 %
# Iota (IOT)                  = $    0.3703 --> "Buy "  since 2018/12/18 06:00 UTC, - 24hrs   -1.52 %  last week   -1.48 %
# Eosio (EOS)                 = $    2.8662 --> "Buy "  since 2019/01/02 18:00 UTC, - 24hrs +  1.26 %  last week +  4.71 %
# Bitcoin Cash (BCH)          = $  275.0000 --> "Sell"  since 2018/11/14 12:00 UTC, - 24hrs  -39.75 %  last week  -53.70 %
# Bitcoin (BTC)               = $ 4121.6000 --> "Buy "  since 2019/01/06 12:00 UTC, - 24hrs +  0.19 %  last week +  4.00 %

# %%
start = '2018-08'
finish = '2019'
btc.plot(start)

# %%
eth.plot(start)

# %%
eos.plot(start)

# %%
xrp.plot(start)

# %%
iot.plot(start)

# %%
neo.plot(start)

# %%
ltc.plot(start)

# %%
eos.plotCandles(days=40)

# %%
eos.trendPlot(start)

# %%
ltc.plotCandles(days=40)

# %%
ltc.trendPlot(start)

# %%
neo.trendPlot()

# %%
iot.trendPlot(start)

# %%
xrp.trendPlot(start)

# %%
eth.trendPlot(start)

# %%
btc.trendPlot(start)

# %% [markdown]
# # DBdata plots

# %%
tot = 0
for coin in CoinData.portfolio.values():
    trend, data = coin.trendFollower(start,finish)
    tot += trend['Profit'].iloc[-1]
tot*100/len(CoinData.portfolio)
