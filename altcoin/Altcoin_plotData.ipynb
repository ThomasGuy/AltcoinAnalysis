# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
from Altcoin.altcoin.getData import getData, showName

# %%
neo = getData('neo', '6h')
btc = getData('btc', '6h')
eos = getData('eos', '6h')
ltc = getData('ltc', '6h')
omg = getData('omg', '6h')

# %%
import os
print(os.path.realpath(showName()))
# Out:
# Altcoin.altcoin.getData
# C:\Users\twguy\MyPython\Altcoin\altcoin

# %%
showName()
# Out:
# Altcoin.altcoin.getData

# %%
neo.drop('volume', axis=1).plot(figsize=(16,8))

# %%
btc.drop('volume', axis=1).plot(figsize=(16,8))

# %%
eos.drop('volume', axis=1).plot(figsize=(16,8))

# %%
ltc.drop('volume', axis=1).plot(figsize=(16,8))

# %%
omg.drop('volume', axis=1).plot(figsize=(16,8))
