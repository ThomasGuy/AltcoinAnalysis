# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
from Altcoin.altcoin.getData import getData, showName
from Altcoin.altcoin.coinData import CoinData
from Altcoin.altcoin.getBitfinexCandles import updateAll

# %%
# updateAll()

# %%
neo = CoinData('neo')
btc = CoinData('btc')
eos = CoinData('eos')
ltc = CoinData('ltc')
omg = CoinData('omg')
xrp = CoinData('xrp')
bch = CoinData('bch')
eth = CoinData('eth')
xmr = CoinData('xmr')

# %%
from TickTocTest.ticktoctest.tickToc import getDBdata

# %%
xlm = CoinData('xlm', getDBdata)
ada = CoinData('ada', getDBdata)
zrx = CoinData('zrx', getDBdata)
avt = CoinData('avt', getDBdata)

# %%
CoinData.portfolio.volatility()

# %%
CoinData.portfolio
# Out:
# {'neo': neo,
#  'btc': btc,
#  'eos': eos,
#  'ltc': ltc,
#  'omg': omg,
#  'xrp': xrp,
#  'bch': bch,
#  'eth': eth,
#  'xmr': xmr,
#  'xlm': xlm,
#  'ada': ada,
#  'zrx': zrx,
#  'avt': avt}

# %%
ltc.plotCandles()

# %%
start = '2017-10-01'
finish = '2019'
btc.trendPlot(start,finish)

# %%
ltc.plot(start,finish)

# %%
eth.trendPlot(start, finish)

# %%
xrp.trendPlot(start,finish)

# %%
bch.trendPlot(start,finish)

# %%
eos.trendPlot(start,finish)

# %%
ltc.trendPlot(start,finish)

# %%
neo.trendPlot(start,finish)

# %%
xmr.trendPlot(start,finish)

# %%
omg.trendPlot(start,finish)

# %% [markdown]
# # DBdata plots

# %%
xlm.trendPlot(start,finish)

# %%
ada.trendPlot(start,finish)

# %%
zrx.trendPlot(start,finish)

# %%
btc.plot(start,finish)

# %%
avt.trendPlot(start,finish)

# %%
nano = CoinData('nano', getDBdata)
nano.trendPlot(start,finish)

# %%
steem = CoinData('steem', getDBdata)
steem.trendPlot(start,finish)

# %%
tot = 0
for coin in CoinData.portfolio.values():
    trend, data = coin.trendFollower(start,finish)
    tot += trend['Profit'].iloc[-1]
tot*100/len(CoinData.portfolio)
# Out:
# 300.7126988616913

# %%
CoinData.portfolio
# Out:
# {'neo': neo,
#  'btc': btc,
#  'eos': eos,
#  'ltc': ltc,
#  'omg': omg,
#  'xrp': xrp,
#  'bch': bch,
#  'eth': eth,
#  'xmr': xmr,
#  'xlm': xlm,
#  'ada': ada,
#  'zrx': zrx,
#  'avt': avt,
#  'nano': nano,
#  'steem': steem}

# %%
len(CoinData.portfolio)
# Out:
# 15

# %%
btcDB = CoinData('btc', getDBdata)

# %%
btcDB.plot('2017-10-01')

# %%
eth.plot('2018-07-01')

# %%
btc.trendPlot('2018-05-20','2018-09')

# %%
btcDB.trendPlot('2018-05-20','2018-09')

# %%
# CoinData.setParams('6h', 10, 28, 76)

# %%
trx3 = CoinData('trx')

# %%
trx3.portfolio
# Out:
# {'neo': neo,
#  'btc': btc,
#  'eos': eos,
#  'ltc': ltc,
#  'omg': omg,
#  'xrp': xrp,
#  'bch': bch,
#  'eth': eth,
#  'xmr': xmr,
#  'xlm': xlm,
#  'ada': ada,
#  'zrx': zrx,
#  'avt': avt,
#  'nano': nano,
#  'steem': steem,
#  'trx': trx}

# %%
trx3.plot(start)

# %%
trx3.plotCandles(days=15)

# %%
trx3.value
# Out:
# 0.023647

# %%
options = {
    'step': '1D',
    'sma': 3,
    'bma': 8,
    'lma': 21
}

# %%
CoinData.setParams(**options)

# %%
btc.plot(start)

# %%
btc.candles(**btc.params)

# %%
btc.value
# Out:
# 6746.3

# %%
btc = CoinData('btc', getDBdata)

# %%
btc.value
# Out:
# 6751.0

# %%
btc.candles(**btc.params)

# %%
btc.plot(start)

# %%
df, cross = btc.getCoinData()

# %%
df.tail()
# Out:
#                             open   close    high          low      volume  \
# MTS
# 2018-08-23 18:00:00  6436.000000  6459.3  6502.6  6270.100000   90.538424
# 2018-08-24 18:00:00  6454.900000  6589.9  6624.4  6359.800000  123.669633
# 2018-08-25 18:00:00  6590.000000  6722.4  6780.1  6585.200000   70.379245
# 2018-08-26 18:00:00  6722.076184  6651.5  6784.1  6557.000000   76.409818
# 2018-08-27 18:00:00  6649.708406  6751.0  6785.0  6649.708406  147.019198
#
#                            sewma        bewma        lewma
# MTS
# 2018-08-23 18:00:00  6445.500361  6435.077177  6606.139561
# 2018-08-24 18:00:00  6517.700180  6469.482249  6604.663183
# 2018-08-25 18:00:00  6620.050090  6525.686193  6615.366892
# 2018-08-26 18:00:00  6635.775045  6553.644817  6618.651821
# 2018-08-27 18:00:00  6693.387523  6597.501524  6630.683810

# %%
zec = CoinData('zec', getDBdata)

# %%
df = zec.getCoinData()

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-4add252522c8> in <module>()
# ----> 1 df.tail()
#
# AttributeError: 'tuple' object has no attribute 'tail'
