# %%
from altcoin.getBitfinexCandles import updateAll

# %%
# updateAll()

# %%
from TickTocTest.ticktoctest.tickToc import getDBdata
from Altcoin.altcoin.coinData import CoinData

# %%
btc = CoinData('btc', getDBdata)
bch = CoinData('bch', getDBdata)
eos = CoinData('eos', getDBdata)
eth = CoinData('eth', getDBdata)
xrp = CoinData('xrp', getDBdata)

# %%
CoinData.portfolio
# Out:
# {'btc': btc, 'bch': bch, 'eos': eos, 'eth': eth, 'xrp': xrp}

# %%
for coin in CoinData.portfolio.values():
    print(f'{coin.name} = ${coin.value}')
# Out:
# btc = $6740.1
# bch = $488.21
# eos = $6.0408
# eth = $243.67
# xrp = $0.56306

# %%
dfs = CoinData.portfolio.portfolioDF()
dfs.keys()
# Out:
# dict_keys(['btc', 'bch', 'eos', 'eth', 'xrp'])

# %%
btc.plot('2018-08-21')

# %%
eth.plot('2018-08-21')

# %%
xrp.plot('2018-08-21')

# %%
bch.plot('2018-08-21')

# %%
eos.plotCandles()

# %%
eos.plot('2018-08-21')
